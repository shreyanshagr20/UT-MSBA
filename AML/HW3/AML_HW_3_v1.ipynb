# %% [markdown]
# <b> MIS 382N: ADVANCED MACHINE LEARNING<b>
#
# Assignment 3
#
# Total points: 70
#
# Due: Monday, October 10 to be submitted via Canvas by 11:59 pm
#
# Your homework should be written in a python notebook. If you prefer, you can work in groups of two. **Please note that only one student per team needs to submit the assignment on Canvas but make sure to include both students' names and UT EIDs.**
#
# For any question that requires a handwritten solution, you may upload scanned images of your solution in the notebook or attach them to the assignment . You may write your solution using markdown as well.
#
# Please make sure your code runs and the graphs and figures are displayed in your notebook before submitting. (%matplotlib inline)

# %% [markdown]
# **This can be an individual assignment or group of 2. If you choose to do it as a group, please specify who you are working with (name and EID), then only one student should submit the homework. Put your name and eid here.**
#
# Name: Shreyansh Agrawal
#
# EID: sa55742
#
# Name:
#
# EID:

# %% [markdown]
# #Question 1: Tensorflow Playground (20 pts)
#
# In this question, you will be playing with [Tensorflow Playground](https://playground.tensorflow.org).
#
#
# Select "Classification" as the Problem Type. Among the four datasets shown in DATA, please select the top left dataset.
#
# Use the following settings as the DEFAULT settings for all subquestions: Learning rate = 0.03, Activation = Tanh, Regularization = None, Ratio of training to test data = 50%, Noise = 0, Batch Size = 30, input as  𝑋1  with  𝑋2 , One hidden layer with 4 neurons.
#
# a) (4 pts) Use the DEFAULT setting and run two experiments - one using Tanh as the activation function and one using the Linear activation function. Report the train, test losses for both at the end of 1000 epochs. What qualitative difference do you observe in the decision boundaries obtained? What do you think is the reason for this?
#
# Ans:
#
# Since the data is non linear, linear activator performs poorly as we are trying to use a linear decision boundary to classify non-linear data. Tanh activator being non linear performs better than linear activator.
# * Tanh activation - Test loss 0.017, Training loss 0.011
# * Linear activation - Test loss 0.499, Training loss 0.499
#
# ---
#
# We will now study the effect of certain variations in the network structure or training process, keeping all other aspects the same as in the DEFAULT setting specified above, with Tanh as the activation.
#
# b) (4 pts) Effect of number of hidden units: Keep other settings the same as in DEFAULT, report the training loss and test loss at the end of 1000 epochs using 2 neurons and 8 neurons in the hidden layer. What do you observe in terms of the decision boundary obtained as the number of neurons increases? What do you think is the reason for this?
#
# Ans:
#
# 8 neurons in the hidden layer fit the data better than 2 neurons (lower test and train errors). With 2 neurons, the decision boundary was more or less linear and with 8 neurons we got more or less a circle. So in a way we can say that we increase the complexity of the model by adding neurons and hence the decision boundary gets more non-linear or complex. The reason is that if you have more neurons you introduce more flexibility in the model which results in a more complex decision boundary. Below are the test and train errors after 1000 epochs:
#
# * 2 neurons - Test loss 0.276, Training loss 0.240
# * 8 neurons - Test loss 0.008, Training loss 0.007
# ---
#
#
# c) (4 pts) Effect of Learning rate and number of epochs: Keep other settings the same as in DEFAULT. For learning rate 10, 1, 0.1, 0.01 and 0.0001, report the train, test losses at the end of 100 epochs, 500 epochs and 1000 epochs respectively. What do you observe from the change of loss vs learning rate, and the change of loss vs epoch numbers? Also report your observations on the training and test loss curve (observe if you see noise for certain learning rates and reason why this is happening).
#
# Ans:
#
# Test Loss
# | Epochs | 10 | 1 | 0.1 | 0.01 | 0.001 |
# | --- | --- | --- | --- | --- | --- |
# | 100 | 0.382 | 0.011 | 0.034 | 0.471 | 0.509 |
# | 500 | 0.076 | 0.002 | 0.012 | 0.103 | 0.469 |
# | 1000 | 0.455 | 0.002 | 0.011 | 0.037 | 0.389 |
#
# Train Loss
# | Epochs | 10 | 1 | 0.1 | 0.01 | 0.001 |
# | --- | --- | --- | --- | --- | --- |
# | 100 | 0.456 | 0.006 | 0.035 | 0.463 | 0.506 |
# | 500 | 0.048 | 0.001 | 0.006 | 0.104 | 0.463 |
# | 1000 | 0.352 | 0.000 | 0.003 | 0.039 | 0.380 |
#
#
# Effect of learning rate with loss:
#
# So from the above tables we can see that as the learning rate decreases, in general, you need more epochs to minimize your error. It makes sense as if you have lower learning rate, you have low step size which will need more steps (or epochs) to converge. For learning rate 0.001, with 100 epochs the loss is 0.509 and it reduces to 0.389 at 100 epochs - it means that it'll need to be further trained to reach the optimal value.4
#
# Effect of epochs with loss:
#
# In general, you loss reduces if you increase the number of epochs especially for lower learning rates as you are moving in the right direction to minimize your loss. For higher learning rates, the reduction in loss with epochs is higher which makes sense as the step size is higher.
#
# On point to note is that for higher learning rate, its possible to diverge from the solution with increase in number of epochs. Here, for learning rate 10, we see that the loss decreases from 100 epochs to 500 epochs, but diverges at 1000 epochs resulting in higher test and train loss.
# Also we observe smoother loss curves for lower learning rate which is mainly due to lower step sizes and for higher learning rate, we see fluctuations which is again due to higher step sizes leading to divergence.
#
# ---
#
#
#
# d) (4 pts) Effect of the number of layers: Change your activation to ReLU and use a single hidden layer with 4 neurons and then add another hidden layer with 3 neurons and train both your models for 1000 epochs. Comments on your final models and decision boundaries and observe your training and test loss curves as well.
#
# Ans:
#
# With 4 neurons we got the train error as 0.005 and test as 0.008 which is a really good performance. The decision boudary is of a closed irregular heptagon and is able to contain the blue dots well. The loss curve rapidly declines at early epochs and then flatlines indicating the model is well trained and generalized and there is no further learning that can be done.
#
# With 2 hidden layers of 4 and 3 neurons, we got a train error of 0.001 and test error of 0.003 which is slighly better than the previous model. The decision boundary is of a closed irregular hexagon and is able to contain the blue dots well. The loss curve is slightly wiggly at the early epochs but drops sharply and then flatlines indicating the model is well trained and generalized and there is no further learning that can be done. The reason for the wiggly curve at the start may be due to the fact that this model is more complex and needs higher epochs to converge to the most optimal solution.
#
# ---
#
# d) (4 pts) Use the DEFAULT setting. Play around with any hyperparameters, network architectures or input features (such as  sin(𝑋1),𝑋21  etc.), and report the best train and test loss you obtain (test loss should be no greater than 0.06). Attach the screenshot showing your full network, output and the parameters. Briefly justify your results, and comment on what helps/what doesn't help with lowering the loss, etc.
#
# Ans:
#
# Using quadratic features with 4 hidden layers and ~200 epochs seemed to give the best result. The test and train error are the lowest i.e. at 0.002. The beauty of this model is that the decision boundary is more or less a circle which is in line with the raw data that we have as input. Also, there is no difference (over ver minimal) between test and train loss indicating the model is very well generalized.
#
# Using appropriate transformations on the input variable seemed to help here even with low epochs. Increasing the number of hidden layers with linear inputs gave good results but the decision boundary was not that great. Also, chaging the activation funtion from linear to non-linear helped but changing from ReLu to Tanh didin't seem to make a lot of difference. Below is the screenshot of our best result.

# %%
from IPython import display
display.Image("Ans_1_d.png")

# %% [markdown]
# # Question 2 : t-SNE (7 pts)
#
# Read this [article](https://erdem.pl/2020/04/t-sne-clearly-explained) on t-SNE, a dimensionality reduction technique for visualization and explain it in your own words in one or two paragraphs.

# %% [markdown]
# # Answer:
#
# t-SNE is a non linear dimensionality reduction method which is used to understand high-dimensional data which is linearly inseparable.
#
# How it works?
# * Algorithm firstly creates a probability distribution which represents the similarity between the data points
# * Similarity is defined as the conditional probability that a data point "I" would pick "j" as its neighbor
# * First Euclidian distance b/w the data point and its neighbors are calculated. This distance is proportional to the probability density under a Gaussian centered at "i"
# * Few more steps are performed to account for high cluster distance, and to make the sum of probability to 1
# * So, now how do we determine the variance of the gaussian distribution? It is determined by the term called "perplexity". It is loosely defined as the number of target neighbors around the central point. SNE uses binary search to get the value of the sigma that generates a probability distribution using the perplexity specified by the user, typically it ranges between 5-50.
#
# Creating low dimensional space
# * Now the idea of t-SNE is to translate the original gaussian distribution in a lower dimensional space using the same number of data point.
# * We are not using gaussian distribution here because it has a short tails which leads to crowding problem. Instead, a student t-distribution with a single degree of freedom is used
# * It provides an advantage that it falls quickly and has a long tail which prevents crowing
#
# Optimizing the distribution of t-SNE using Gradient Descent
# * To optimize this distribution t-SNE is using Kullback-Leibler divergence between the conditional probabilities p i|j and q i|j​
# * A gradient is calculated for each point and describes how “strong” it should be pulled and the direction it should choose
#
# Optimizing the process
# * Early Compression: To avoid clustering at a early stage, t-SNE is adding a L2 penalty to the cost function to avoid algorithm not to focus on the local groups.
# * Early Exaggeration: We multiply Pi|j in early stages which enables moving clusters of Qi|j more, as a result clusters don't get in each other's way
#
# Use in CNN
# * Deep CNN networks are black box models, and its becomes impossible to interpret the layers given they are in a very high dimension.
# * But using t-SNE, we can create maps to display which input data seems "similar" for the network
#
# Although it’s an iterative, non-deterministic process, and can't be used for ML model training purposes, it is a super powerful technique to understand high-dimensional datasets and is used widely in the industry

# %% [markdown]
# # Question 3: PCA (8 pts)
#
# Explain the principle of Principal Component Analysis algorithm and in what sense is the selection of the eigenvectors to represent the data is an optimal choice.  How do you reconstruct (a noisy version of) the original data from the eigenvectors and the loadings?

# %% [markdown]
# # Answer
#
# PCA is a feature extraction method that is aimed to reduced the dimensionality of the feature space. Broadly speaking, PCA projects the data from a n dimensional space to a m dimensional space (where m<n) by linearly combining the n features so that maximum amount of variance is retained. Below is the algorithm of the same -
#
# * A typical way to do PCA is to break the original n dimensional space into eigenvalues and eigenvectors through Singular Value Decomposition (SVD)
# * Suppose your original vector is X, then X . X(transpose)=P . D . P(inverse) such that P is your eigenvector and D contains eigenvalues at the diagonal elements and rest all elements in D are zero. And X . X(transpose) is your covariance matrix. The eigenvalues on the diagonal of D will be associated with the corresponding column in P i.e., the first element of D is λ₁ and the corresponding eigenvector is the first column of P
# * Now you need to sort the eigen values from largest to smallest and correspondingly sort your eigen vectors. You now choose the top m values.
# * Now, X* = X.P* where P* is the matrix that contains the top m eigen vectors as columns. X* is your representation of data (or projection) in the m dimensional space (i.e. your transformed data)
#
# Now the eigenvectors represent the directions and the eigenvalues loosely speaking indicate how much variance is explained in the direction of the eigen vector. We select the top eigenvalues implying that we are selecting the top eigenvectors (or directions) which explain the maximum variance in the data. Which means the first principal component will explain the maximum variance, the 2nd will explain the end highest variance and so on. Idea of PCA is to represent a "n" dimensional space in "m" dimensions without much loss of information (i.e. variance), so selecting the eigenvectors the above described way is the optimal choice as it ensures that maximum variance is retained for a given value of m and the reconstruction loss is the lowest.
#
# The way you reconstruct (a noisy version of) the original data is by taking the dot product of the transpose of eigen vector with the transformed data. i.e. X (noisy version) = P*(transpose) . X*

# %% [markdown]
# # Question 4: Outlier detection using PyOD (20 pts)
#
# Outlier detection, or anomaly detection is usually an unsupervised learning task where the objective is to identify suspicious observations in data. It has been widely used in military surveillance for enemy activities to prevent attacks, intrusion detection in cyber security, fraud detection for credit cards, etc.
#
# PyOD is a comprehensive and scalable Python library for detecting outlying objects in multivariate data. PyOD includes more than 30 detection algorithms and provides unified APIs which makes it quite handy to use. In this question, you will play with PyOD, explore three different outlier detection algorithms and compare their performances. First let's install PyOD.
#
# ```
# # install pyod using pip first
# !pip install pyod
# ```
#
# You can load the data stored in 'Q3_train_dataset.csv' and 'Q3_test_dataset.csv' using the following codes.
#
# ```
# import pandas as pd
# # Load data code goes here
# train_df = pd.read_csv('Q3_train_dataset.csv')
# test_df = pd.read_csv('Q3_test_dataset.csv')
#
# X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
# y_train = train_df[['y_train']].to_numpy()
# X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
# y_test = test_df[['y_test']].to_numpy()
# ```
#
#  `X_train` and `X_test` contain the features, with the dimension of 5. `y_train` and `y_test` store the outlier labels, 0 means normal data, 1 means outlier data.
#
# a) **(5 pts)** **Fit `X_train` to a outlier detection model k Nearest Neighbors (kNN) using PyOD**, this [page](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.mcd) will provide some functions you may need.
#
# ```
# from pyod.models.knn import KNN
# clf = KNN() # initialize KNN class using the default parameters
#
# # YOUR CODE SHOULD COME HERE, FIT THE MODEL USING X_TRAIN
# ```
# **Use the fitted model to predict the outlier labels of `X_test`. Compute the raw outlier scores on `X_test` using `decision_function()`.**
#
# **Run PyOD's `evaluate_print()` function using the test set ground truth outlier labels and the raw outlier scores predicted by the model, to compute the ROC and Precision@n results .**
#
# ```
# from pyod.utils.data import evaluate_print
# ```
#
# b) **(5 pts)** `X_train` and `X_test` are 5-dimension features, which makes it impossible to visualize them in Euclidean plane. But we can use Principal Component Analysis (PCA) to reduce the dimensions of `X_train` and `X_test` to 2, and then plot them. You may want to use `fit_and_transform()` function.
#
#
# ```
# from sklearn.decomposition import PCA
#
# pca = PCA(n_components=2)
#
# # Fit pca to X_train and X_test and transform
# train_principalComponents = # IMPLEMENT
# test_principalComponents = # IMPLEMENT
# ```
#
# After reducing the dimension to 2, now you can visualize the outliers using PyOD's `visualize()` function. Please plot the visualization. You may find [this](https://pyod.readthedocs.io/en/latest/pyod.utils.html#module-pyod.utils.example) useful on how to use `visualize()` .
#
# ```
# from pyod.utils.example import visualize
# ```
#
# Now you should be able to observe the ground truth outliers and the outliers predicted by the model.
#
#
# c) **(10 pts)** Apply the same process as in (a) and (b) to the following two models, and visualize the outlier results. Please compare the performance of the two models in terms of their ROC, Precision@n, and what you observe from the two visualizations.
#
# *   [Isolation-Based model - Isolation-based anomaly detection using Nearest-Neighbor Ensembles (INNE)](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.inne)
#
# ```
# from pyod.models.inne import INNE
# ```
#
# # Answer:

# %%
# Only use this code block if you are using Google Colab.
# If you are using Jupyter Notebook, please ignore this code block. You can directly upload the file to your Jupyter Notebook file systems.
from google.colab import files

## It will prompt you to select a local file. Click on “Choose Files” then select and upload the file. 
## Wait for the file to be 100% uploaded. You should see the name of the file once Colab has uploaded it.
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c270fb62-09db-4bbd-ba75-661aea461750" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c270fb62-09db-4bbd-ba75-661aea461750">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# install pyod using pip first
# !pip install pyod

# %%
import pandas as pd
# Load data code goes here
train_df = pd.read_csv('Q3_train_dataset.csv')
test_df = pd.read_csv('Q3_test_dataset.csv')

X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
y_train = train_df[['y_train']].to_numpy()
X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
y_test = test_df[['y_test']].to_numpy()

# %%
# (a)
from pyod.models.knn import KNN
clf = KNN() # initialize KNN class using the default parameters

# fit the model using X_train

# YOUR CODE SHOULD COME HERE

# %%
from pyod.utils.data import evaluate_print
# predict the outlier labels of X_test using the trained model, compute the raw outlier scores on X_test using decision_function()
# then use evaluate_print() to print out the evaluation results

# YOUR CODE SHOULD COME HERE

# %%
# (b)
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

# Fit pca to X_train and X_test and transform 
train_principalComponents = # YOUR CODE SHOULD COME HERE
test_principalComponents = # YOUR CODE SHOULD COME HERE

from pyod.utils.example import visualize
# Visualize the ground truth outliers and predicted outliers using visualize()

# YOUR CODE SHOULD COME HERE

# %%
# (c)
from pyod.models.inne import INNE


# YOUR CODE SHOULD COME HERE

# %% [markdown]
# # Solutions:

# %% [markdown]
# # Question 5: Pre-processing and sampling (15 pts)
#
# The following dataset contains House prices describing the sales of individual residential property in Ames, Iowa data with explanatory variables describing almost every aspect of residential homes and dependent variable being SalePrice. Here, some cells of most columns in the dataset contain NaN values.

# %%
# Only use this code block if you are using Google Colab.
# If you are using Jupyter Notebook, please ignore this code block. You can directly upload the file to your Jupyter Notebook file systems.
from google.colab import files

## It will prompt you to select a local file. Click on “Choose Files” then select and upload the file. 
## Wait for the file to be 100% uploaded. You should see the name of the file once Colab has uploaded it.
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c8d069e0-5332-4874-9b0f-676b22f2ea13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8d069e0-5332-4874-9b0f-676b22f2ea13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd 
import numpy as np 
import scipy.stats as stats
import math
import matplotlib.pyplot as plt
np.random.seed(100)

data = pd.read_csv("sales_data.csv")
data.head()

# %% [markdown]
# a)**(2 pts)**Print the number of NaN, NULL and empty values (combined sum) in each column.

# %% [markdown]
# b)**(3 pts)**Create a copy of `data`, and name it `data_dm`, then create a new column in `data_dm` named `binned_garage_yr_built` and apply binning to the column `garage_yr_built`. Use `pandas.cut()` and modify its parameter list as below:
#
# ```
# bins=[1900, 1930, 1960, 1990, 2020]
# labels=['1900-1930', '1930-1960', '1960-1990', '1990-2020']
# include_lowest=True
# ```
# Next, perform one-hot encoding on this new column.

# %% [markdown]
# c)**(3 pts)**Drop the columns which have more than 90%, 95% and 98% of missing values. List the columns which get dropped in each of the cases and observe the number of columns that get dropped in each of the cases as well.

# %% [markdown]
# d)**(2 pts)**Take a sample of 800 rows at random and compute its mean. Compare the result with the population mean

# %%
np.random.seed(6)
sample_ages = np.random.choice(a= data['SalePrice'], size=800)
#Sample mean

#Population mean

# %% [markdown]
# e) i)**(2pts)** Calculate 95% confidence intervals for SalePrice with a sample size of 100.
#
# ii)**(3pts)** Calculate 95 % confidence intervals for 100 different trials with a sample size of 500. Plot the confidence intervals and interpret how it captures the population mean.

# %%
np.random.seed(10)
sample_size = 100
sample = np.random.choice(a= data_dm['SalePrice'],
                          size = sample_size)
sample_mean = sample.mean()

#Get the critical Z value


#Get population standard deviation



#margin of error
margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size)) 

#confidence interval
confidence_interval = (sample_mean - margin_of_error,
                       sample_mean + margin_of_error)  

#Print confidence interval and true mean value

# %%
np.random.seed(12)

#define the sample size

intervals = []
sample_means = []

for sample in range(100):
    sample = np.random.choice(a= data_dm['SalePrice'], size = sample_size)
    sample_mean = sample.mean()
    sample_means.append(sample_mean)
    #compute z critical value

    #compute population std dev        
  
    
    margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size))
    confidence_interval = (sample_mean - margin_of_error,
                           sample_mean + margin_of_error)  
    
    intervals.append(confidence_interval)
    

plt.figure(figsize=(13, 9))

plt.errorbar(x=np.arange(0.1, 100, 1), 
             y=sample_means, 
             yerr=[(top-bot)/2 for top,bot in intervals],
             fmt='o')

plt.hlines(xmin=0, xmax=25,
           y=data['SalePrice'].mean(), 
           linewidth=2.0,
           color="red")
plt.title('Confidence Intervals for 100 Trials', fontsize = 20)
plt.show()

# %% [markdown]
# ### Solution:
